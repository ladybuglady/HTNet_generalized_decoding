# %% [markdown]
# # Plot the main results from the paper

# %% [markdown]
# Plots Figs. 2-5 from the paper, after having run train_decoders.py.

# %%
# %matplotlib inline
from plot_utils import plot_model_accs, plot_weights_interp, plot_overlap_trainnum, plot_fine_tuning
# Out:
# /home/zeynep/anaconda3/envs/zoe1/lib/python3.7/site-packages/outdated/utils.py:18: OutdatedCacheFailedWarning: Failed to use cache while checking for outdated package.
# Set the environment variable OUTDATED_RAISE_EXCEPTION=1 for a full traceback.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   **kwargs
# /home/zeynep/anaconda3/envs/zoe1/lib/python3.7/site-packages/outdated/utils.py:18: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.3.8, the latest is 0.4.0.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   **kwargs

# %% [markdown]
# ### Set parameters

# %%
rootpath = '/data1/users/zeynep/' # pulling results from rootpath+dataset directory
#rootpath = '/data1/users/stepeter/htnet_generalized_data/'
dataset = 'move_rest_ecog'
compare_models = True # if True, plot across different models; if False, plot across different HilbertNet measures

#ecog_roi_proj_lp = 'data1/users/stepeter/htnet_generalized_data/ecog_dataset/proj_mat/' # path to projection matrices

# %% [markdown]
# ## Test accuracy across model type (Fig. 2) or across different spectral measures (Fig. S2)

# %%
fig, dfs_all = plot_model_accs(rootpath, dataset, compare_models=compare_models)

# View stats
# test_acc_mod_stats(dfs_all)

# Save figure
# fig_sp = rootpath+dataset+'/figs/'
# fig_name = 'fig_accs_model_compare' if compare_models else 'fig_accs_hilbmeas_compare'
# fig.savefig(fig_sp+fig_name+'.png',
#             format='png',  transparent= True,dpi=dpi_plt,
#             bbox_inches = 'tight', pad_inches = 0.01,
#             )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-5d42e88d29b7> in <module>
# ----> 1 fig, dfs_all = plot_model_accs(rootpath, dataset, compare_models=compare_models)
#       2
#       3 # View stats
#       4 # test_acc_mod_stats(dfs_all)
#       5
#
# ~/ForkedRepos/HTNet_generalized_decoding/plot_utils.py in plot_model_accs(root_path, dataset, nb_classes, compare_models, dpi_plt)
#     153                 else:
#     154                     lp_curr = lp_curr.replace(replace_str,test_type)
# --> 155                     tmp_vals = np.load(lp_curr+'acc_gen_'+model_type+'_'+str(n_folds)+'.npy')
#     156                     for j in range(n_accs):
#     157                         for p in range(n_folds):
#
# ~/anaconda3/envs/zoe1/lib/python3.7/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
# ...

# %% [markdown]
# ## HTNet fine-tuning (Fig. 3)

# %%
fig, df_ft = plot_fine_tuning(rootpath + dataset)

# View stats
# test_finetuning_stats(df_ft)

# Save figure
# fig_sp = rootpath+dataset+'/figs/'
# fig_name = 'fig_finetuning.png'
# fig.savefig(fig_sp+fig_name+'.png',
#             format='png',  transparent= True,dpi=dpi_plt,
#             bbox_inches = 'tight', pad_inches = 0.01,
#             )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-2bd9ec7e0159> in <module>
# ----> 1 fig, df_ft = plot_fine_tuning(rootpath + dataset)
#       2
#       3 # View stats
#       4 # test_finetuning_stats(df_ft)
#       5
#
# ~/ForkedRepos/HTNet_generalized_decoding/plot_utils.py in plot_fine_tuning(root_path, model, dpi_plt)
#    1053
#    1054         # Load param file from training/testing
# -> 1055         file_pkl = open(root_path + '/combined_sbjs_' + spec_meas[ind] + '/param_file.pkl', 'rb')
#    1056         params_dict = pickle.load(file_pkl)
#    1057         file_pkl.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data1/users/zeynep/move_rest_ecog/combined_sbjs_power/param_file.pkl'

# %% [markdown]
# ## HTNet interpretability (Fig. 4)

# %% [markdown]
# Takes ~1 minute to run

# %%
spec_lp = rootpath + dataset  + '/combined_sbjs_power/' # path to pre-computed difference spectrograms
fig = plot_weights_interp(rootpath, dataset, ecog_roi_proj_lp, spec_lp)

# Save figure
# fig_sp = '/data2/users/stepeter/cnn_hilb_datasets/naturalistic_v3/figs/'
# fig_name = 'fig_model_interp.png'
# fig.savefig(fig_sp+fig_name,
#             format='png',  transparent= True,dpi=dpi_plt,
#             bbox_inches = 'tight', pad_inches = 0.01,
#             )
# Out:
# conv2d: mean
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-3e494123cd90> in <module>
#       1 spec_lp = rootpath + dataset  + '/combined_sbjs_power/' # path to pre-computed difference spectrograms
# ----> 2 fig = plot_weights_interp(rootpath, dataset, ecog_roi_proj_lp, spec_lp)
#       3
#       4 # Save figure
#       5 # fig_sp = '/data2/users/stepeter/cnn_hilb_datasets/naturalistic_v3/figs/'
#
# ~/ForkedRepos/HTNet_generalized_decoding/plot_utils.py in plot_weights_interp(root_path, dataset, roi_proj_lp, spec_lp, mod_type, nb_classes, dat_type, temp_conv_layer, weight_type, srate, bode_type, custom_rois, dpi_plt, vscale_val, epoch_times)
#     391     axes[0,1].set_position([x0-.06,y0,width,height])
#     392     print(temp_conv_layer+': '+weight_type)
# --> 393     file_pkl = open(lp+'param_file.pkl', 'rb')
# ...

# %% [markdown]
# ## Effects of electrode overlap and number of training participants on test accuracy (Fig. 5)

# %%
fig = plot_overlap_trainnum(rootpath+dataset+'/')

# Save figure
# fig_sp = rootpath+dataset+'/figs/'
# fig_name = 'fig_ntra_frac_overlap'
# fig.savefig(fig_sp+fig_name+'.png',
#             format='png',  transparent= True,dpi=dpi_plt,
#             bbox_inches = 'tight', pad_inches = 0.01,
#             )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-a79c1d5e5b6e> in <module>
# ----> 1 fig = plot_overlap_trainnum(rootpath+dataset+'/')
#       2
#       3 # Save figure
#       4 # fig_sp = rootpath+dataset+'/figs/'
#       5 # fig_name = 'fig_ntra_frac_overlap'
#
# ~/ForkedRepos/HTNet_generalized_decoding/plot_utils.py in plot_overlap_trainnum(lp, dpi_plt)
#     700
#     701     # Load in results
# --> 702     df_sbj_ntra = pd.read_csv(lp+'ntra_df.csv')
#     703     df_sbj_fo = pd.read_csv(lp+'frac_overlap_df.csv')
#     704
#
# ...
